# %% [markdown]
# # GraphRAG Quickstart

# %% [markdown]
# ## Prerequisites
# Install 3rd party packages, not part of the Python Standard Library, to run the notebook

# %%
! pip install devtools python-magic requests tqdm
# Out:
# Requirement already satisfied: devtools in /graphrag-accelerator/.venv/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: python-magic in /graphrag-accelerator/.venv/lib/python3.10/site-packages (0.4.27)
# Requirement already satisfied: requests in /graphrag-accelerator/.venv/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: tqdm in /graphrag-accelerator/.venv/lib/python3.10/site-packages (4.66.5)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from devtools) (2.4.1)
# Requirement already satisfied: executing>=1.1.1 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from devtools) (2.1.0)
# Requirement already satisfied: pygments>=2.15.0 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from devtools) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from requests) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from requests) (2024.8.30)
# Requirement already satisfied: six>=1.12.0 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from asttokens<3.0.0,>=2.0.0->devtools) (1.16.0)

# %%
import getpass
import json
import time
from pathlib import Path

import magic
import requests
from devtools import pprint
from tqdm import tqdm

# %% [markdown]
# ## (REQUIRED) User Configuration
# Set the API subscription key, API base endpoint, and some file directory names that will be referenced later in the notebook.

# %% [markdown]
# #### API subscription key
#
# APIM supports multiple forms of authentication and access control (e.g. managed identity). For this notebook demonstration, we will use a **[subscription key](https://learn.microsoft.com/en-us/azure/api-management/api-management-subscriptions)**. To locate this key, visit the Azure Portal. The subscription key can be found under `<my_resource_group> --> <API Management service> --> <APIs> --> <Subscriptions> --> <Built-in all-access subscription> Primary Key`. For multiple API users, individual subscription keys can be generated.

# %%
ocp_apim_subscription_key = getpass.getpass(
    "Enter the subscription key to the GraphRag APIM:"
)

"""
"Ocp-Apim-Subscription-Key": 
    This is a custom HTTP header used by Azure API Management service (APIM) to 
    authenticate API requests. The value for this key should be set to the subscription 
    key provided by the Azure APIM instance in your GraphRAG resource group.
"""
headers = {"Ocp-Apim-Subscription-Key": ocp_apim_subscription_key}

# %% [markdown]
# #### Setup directories and API endpoint
#
# For demonstration purposes, please use the provided `get-wiki-articles.py` script to download a small set of wikipedia articles or provide your own data (graphrag requires txt files to be utf-8 encoded).

# %%
"""
These parameters must be defined by the notebook user:

- file_directory: a local directory of text files. The file structure should be flat,
                  with no nested directories. (i.e. file_directory/file1.txt, file_directory/file2.txt, etc.)
- storage_name:   a unique name to identify a blob storage container in Azure where files
                  from `file_directory` will be uploaded.
- index_name:     a unique name to identify a single graphrag knowledge graph index.
                  Note: Multiple indexes may be created from the same `storage_name` blob storage container.
- endpoint:       the base/endpoint URL for the GraphRAG API (this is the Gateway URL found in the APIM resource).
"""

file_directory = "testdata"
storage_name = "gragstorage"
index_name = "gragidx01"
endpoint = "https://apim-nxa33djtbfsky.azure-api.net"

# %%
assert (
    file_directory != "" and storage_name != "" and index_name != "" and endpoint != ""
)

# %% [markdown]
# ## Upload Files
#
# For a demonstration of how to index data in graphrag, we first need to ingest a few files into graphrag.

# %%
def upload_files(
    file_directory: str,
    storage_name: str,
    batch_size: int = 100,
    overwrite: bool = True,
    max_retries: int = 5,
) -> requests.Response | list[Path]:
    """
    Upload files to a blob storage container.

    Args:
    file_directory - a local directory of .txt files to upload. All files must have utf-8 encoding.
    storage_name - a unique name for the Azure storage blob container.
    batch_size - the number of files to upload in a single batch.
    overwrite - whether or not to overwrite files if they already exist in the storage blob container.
    max_retries - the maximum number of times to retry uploading a batch of files if the API is busy.

    NOTE: Uploading files may sometimes fail if the blob container was recently deleted
    (i.e. a few seconds before. The solution "in practice" is to sleep a few seconds and try again.
    """
    url = endpoint + "/data"

    def upload_batch(
        files: list, storage_name: str, overwrite: bool, max_retries: int
    ) -> requests.Response:
        for _ in range(max_retries):
            response = requests.post(
                url=url,
                files=files,
                params={"storage_name": storage_name, "overwrite": overwrite},
                headers=headers,
            )
            # API may be busy, retry
            if response.status_code == 500:
                print("API busy. Sleeping and will try again.")
                time.sleep(10)
                continue
            return response
        return response

    batch_files = []
    accepted_file_types = ["text/plain"]
    filepaths = list(Path(file_directory).iterdir())
    for file in tqdm(filepaths):
        # validate that file is a file, has acceptable file type, has a .txt extension, and has utf-8 encoding
        if (
            not file.is_file()
            or file.suffix != ".txt"
            or magic.from_file(str(file), mime=True) not in accepted_file_types
        ):
            print(f"Skipping invalid file: {file}")
            continue
        # open and decode file as utf-8, ignore bad characters
        batch_files.append(
            ("files", open(file=file, mode="r", encoding="utf-8", errors="ignore"))
        )
        # upload batch of files
        if len(batch_files) == batch_size:
            response = upload_batch(batch_files, storage_name, overwrite, max_retries)
            # if response is not ok, return early
            if not response.ok:
                return response
            batch_files.clear()
    # upload remaining files
    if len(batch_files) > 0:
        response = upload_batch(batch_files, storage_name, overwrite, max_retries)
    return response


response = upload_files(
    file_directory=file_directory,
    storage_name=storage_name,
    batch_size=100,
    overwrite=True,
)
if not response.ok:
    print(response.text)
else:
    print(response)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 196.35it/s]
# <Response [200]>

# %% [markdown]
# ## Build an Index
#
# After data files have been uploaded, we can construct a knowledge graph by building a search index.

# %%
def build_index(
    storage_name: str,
    index_name: str,
) -> requests.Response:
    """Create a search index.
    This function kicks off a job that builds a knowledge graph index from files located in a blob storage container.
    """
    url = endpoint + "/index"
    request = {"storage_name": storage_name, "index_name": index_name}
    return requests.post(url, params=request, headers=headers)


response = build_index(storage_name=storage_name, index_name=index_name)
print(response)
if response.ok:
    print(response.text)
else:
    print(f"Failed to submit job.\nStatus: {response.text}")
# Out:
# <Response [200]>
# {"status":"Indexing job scheduled"}

# %% [markdown]
# ### Check status of an indexing job
#
# Please wait for your index to reach 100 percent completion before continuing on to the next section (running queries). You may rerun the next cell multiple times to monitor status. Note: the indexing speed of graphrag is directly correlated to the TPM quota of the Azure OpenAI model you are using.

# %%
def index_status(index_name: str) -> requests.Response:
    url = endpoint + f"/index/status/{index_name}"
    return requests.get(url, headers=headers)


response = index_status(index_name)
pprint(response.json())
# Out:
# {
#     'status_code': 200,
#     'index_name': 'gragidx01',
#     'storage_name': 'gragstorage',
#     'status': 'complete',
#     'percent_complete': 100.0,
#     'progress': '16 out of 16 workflows completed successfully.',
# }

# %% [markdown]
# ## Query
#
# Once an indexing job is complete, the knowledge graph is ready to query. Two types of queries (global and local) are currently supported. We encourage you to try both and experience the difference in responses. Note that query response time is also correlated to the TPM quota of the Azure OpenAI model you are using.

# %%
# a helper function to parse out the result from a query response
def parse_query_response(
    response: requests.Response, return_context_data: bool = False
) -> requests.Response | dict[list[dict]]:
    """
    Print response['result'] value and return context data.
    """
    if response.ok:
        print(json.loads(response.text)["result"])
        if return_context_data:
            return json.loads(response.text)["context_data"]
        return response
    else:
        print(response.reason)
        print(response.content)
        return response

# %% [markdown]
# ### Global Query
#
# Global queries are resource-intensive, but provide good responses to questions that require an understanding of the dataset as a whole.

# %%
# %%time


def global_search(index_name: str | list[str], query: str, community_level: int) -> requests.Response:
    """Run a global query over the knowledge graph(s) associated with one or more indexes"""
    url = endpoint + "/query/global"
    # optional parameter: community level to query the graph at (default for global query = 1)
    request = {"index_name": index_name, "query": query, "community_level": community_level}
    return requests.post(url, json=request, headers=headers)


# perform a global query
global_response = global_search(
    index_name=index_name, query="Summarize the main topics found in this data", community_level=1
)
global_response_data = parse_query_response(global_response, return_context_data=True)
global_response_data
# Out:
# ### Summary of Main Topics
#
# The dataset covers a wide range of topics, focusing on the cultural, economic, historical, and political significance of various regions and entities in the United States. Below is a detailed summary of the main topics:
#
# #### New York State
# New York State is highlighted for its cultural, financial, and educational significance, with New York City being a major urban locale influencing finance, technology, media, and entertainment. The state also has a diverse population and significant historical landmarks [Data: Reports (137, 194)]. The Erie Canal's historical and economic impact on cities like Buffalo, Rochester, and Syracuse is also noted [Data: Reports (203)]. Lower Manhattan is recognized as a financial and historical hub, including Wall Street and the New York Stock Exchange [Data: Reports (145)].
#
# #### Washington State
# Washington State is a significant entity in the Pacific Northwest, known for its diverse climate, strong political activities, and substantial economic contributions. Key sectors include agriculture, technology, and retail, with major companies like Amazon, Microsoft, and Costco headquartered there [Data: Reports (71, 63)]. The state's diverse ethnic communities and significant geographical features like the Cascade Range and the Olympic Peninsula are also highlighted [Data: Reports (173, 181)].
#
# #### District of Columbia
# The District of Columbia serves as the central entity in its community, encompassing political, educational, and media institutions. It is home to significant educational institutions like Georgetown University and influential media organizations such as The Washington Post. The legislative and governance framework revolves around the United States Congress and various legislative acts [Data: Reports (134, 132)]. The Washington Metro and Union Station are crucial transportation hubs [Data: Reports (126, 15)].
#
# #### California
# California is noted for its economic and cultural contributions, particularly in entertainment, media, and technology. Los Angeles is a major hub, home to Hollywood and extensive transportation networks [Data: Reports (53)]. The California Water Wars and the Ports of Los Angeles and Long Beach are critical to the state's development and international trade [Data: Reports (53, 53)]. The state's judicial system and governance, including the University of California system, are also significant [Data: Reports (30, 50)].
#
# #### Alaska
# Alaska's historical and economic significance is highlighted through events like the Good Friday Earthquake and the establishment of the Alaska Permanent Fund. Key regions like Anchorage and Fairbanks serve as central hubs, and the Alaska Railroad plays a crucial role in connecting various regions [Data: Reports (191, 101, 188, 174, 189)]. The smallpox outbreaks and the role of the Iroquois Confederacy are also noted [Data: Reports (83, 195)].
#
# #### Other Notable Topics
# - **Historical Events and Figures**: The influence of George Washington, the Stonewall Riots, and the Continental Congress are significant historical topics [Data: Reports (155, 143, 146)].
# - **Educational Institutions**: Universities like Cornell University, the University of Washington, and George Washington University are central to their respective regions' academic landscapes [Data: Reports (212, 28, 118)].
# - **Geopolitical and Environmental Issues**: The Pacific Northwest's historical treaties, the California Water Wars, and the Klamath River Project are notable geopolitical and environmental issues [Data: Reports (98, 53, 5)].
#
# ### Conclusion
# The dataset provides a comprehensive overview of various regions and entities in the United States, highlighting their cultural, economic, historical, and political significance. Each region's unique contributions and challenges are well-documented, offering valuable insights into the diverse landscape of the United States.
# CPU times: user 34.6 ms, sys: 4.97 ms, total: 39.6 ms
# Wall time: 35.2 s
# {'reports': [{'id': '180',
#    'title': 'Central Valley and Sacramento-San Joaquin River Delta',
#    'occurrence weight': 0.20512820512820512,
#    'content': "# Central Valley and Sacramento-San Joaquin River Delta\n\nThe community revolves around the Central Valley, a significant agricultural and energy-producing region in California, and the Sacramento-San Joaquin River Delta, a critical water supply hub. The Central Valley is bounded by various mountain ranges and is divided into the Sacramento Valley and the San Joaquin Valley by the Delta. The region is also home to specific flora such as the Fremont cottonwood and Valley oak.\n\n## Central Valley as a key agricultural and energy region\n\nThe Central Valley is a large and fertile agricultural region located in the center of California, known for its significant agricultural output and deposits of crude oil and natural gas. This region is crucial for California's economy, providing a substantial portion of the state's agricultural products and energy resources. The Central Valley's productivity is supported by its rich soil and the water supplied by the Sacramento and San Joaquin Rivers [Data: Entities (15); Relationships (14, 410, 411)].\n\n## Sacramento-San Joaquin River Delta's critical role in water supply\n\nThe Sacramento-San Joaquin River Delta serves as a critical water supply hub for California, providing drinking water for nearly 23 million people and supporting agricultural needs. The Delta divides the Central Valley into the Sacramento Valley and the San Joaquin Valley, playing a vital role in the region's water management and agricultural success. The Delta's importance is underscored by its role in sustaining both human populations and agricultural activities [Data: Entities (140); Relationships (71, 404, 436, 438)].\n\n## Geographical boundaries of the Central Valley\n\nThe Central Valley is geographically bounded by several mountain ranges: the Coastal Mountain Ranges to the west, the Sierra Nevada to the east, the Cascade Range to the north, and the Tehachapi Mountains to the south. These natural boundaries contribute to the region's unique climate and environmental conditions, which are conducive to its agricultural productivity. Understanding these geographical boundaries is essential for comprehending the region's environmental and economic dynamics [Data: Entities (146, 148); Relationships (405, 406, 407, 402)].\n\n## Flora thriving in the Central Valley\n\nThe Central Valley is home to specific flora such as the Fremont cottonwood and Valley oak, which thrive in the region's unique environmental conditions. These trees are indicative of the Valley's rich biodiversity and contribute to the ecological balance of the area. The presence of these species highlights the importance of preserving the natural habitats within the Central Valley to maintain its ecological health [Data: Entities (224, 225); Relationships (408, 409)].\n\n## Economic challenges faced by the Central Valley\n\nDespite its significant agricultural and energy output, the Central Valley faces economic challenges. These challenges include issues related to water management, environmental sustainability, and economic disparities within the region. Addressing these challenges is crucial for ensuring the long-term viability and prosperity of the Central Valley, which is vital for California's overall economic health [Data: Entities (15)].",
#    'rank': 8.5,
#    'index_name': 'gragidx01',
#    'index_id': '180'},
#   {'id': '131',
#    'title': 'Potomac River and Washington Aqueduct Community',
#    'occurrence weight': 0.1794871794871795,
#    'content': "# Potomac River and Washington Aqueduct Community\n\nThe community revolves around the Potomac River and the Washington Aqueduct, which is operated by the Army Corps of Engineers. The Potomac River is a significant water source for the Washington Aqueduct, which in turn supplies drinking water to various regions including Washington, D.C., Fairfax County, Arlington, and Falls Church. The community also includes several reservoirs such as Dalecarlia, Georgetown, and McMillan, which are integral to the water treatment and storage process.\n\n## Potomac River as a central water source\n\nThe Potomac River is a crucial water source for the Washington Aqueduct, which supplies drinking water to Washington, D.C., and surrounding areas. The river's strategic location and utility make it an integral part of the city's infrastructure and daily life. The Potomac River also forms the southern border of the District of Columbia and is a prominent feature of the national capital [Data: Entities (1106); Relationships (1480, 795, 1719)].\n\n## Washington Aqueduct's operational significance\n\nThe Washington Aqueduct, operated by the Army Corps of Engineers, is responsible for providing water to the District of Columbia Water and Sewer Authority (D.C. Water) and other regions such as Fairfax County, Arlington, and Falls Church. The aqueduct's role in water supply is critical for the daily functioning and public health of these areas [Data: Entities (1575, 1576); Relationships (1719, 1913, 1911, 1907, 1906, 1912)].\n\n## Role of reservoirs in water treatment and storage\n\nThe Dalecarlia, Georgetown, and McMillan Reservoirs are key components of the water treatment and storage process for the Washington Aqueduct. These reservoirs ensure that the water supplied to the community is treated and stored properly, maintaining the quality and safety of the drinking water [Data: Entities (1586, 1587, 1588); Relationships (1908, 1909, 1910)].\n\n## District of Columbia Water and Sewer Authority's role\n\nThe District of Columbia Water and Sewer Authority (D.C. Water) is an independent authority that provides drinking water and wastewater collection in Washington, D.C. The authority relies on the Washington Aqueduct for its water supply, making it a crucial entity in the community's water infrastructure [Data: Entities (1574); Relationships (1906)].\n\n## Fairfax County's dependency on the Washington Aqueduct\n\nFairfax County, Virginia, receives its drinking water from the Washington Aqueduct. This dependency highlights the interconnectedness of the community and the importance of the aqueduct in ensuring a reliable water supply for the county's residents [Data: Entities (1581); Relationships (1913)].\n\n## Arlington's water supply from the Washington Aqueduct\n\nArlington, Virginia, also receives its drinking water from the Washington Aqueduct. The aqueduct's role in supplying water to Arlington underscores its significance in the broader community's water infrastructure [Data: Entities (1589); Relationships (1911)].\n\n## Falls Church's reliance on the Washington Aqueduct\n\nFalls Church, Virginia, is another region that depends on the Washington Aqueduct for its drinking water. This reliance further emphasizes the aqueduct's critical role in the community's water supply network [Data: Entities (1590); Relationships (1912)].\n\n## Fairfax Connector's operation in Fairfax County\n\nThe Fairfax Connector is a public bus system operating in Fairfax County, Virginia. While not directly related to the water supply, the presence of this transportation system indicates the interconnectedness and infrastructure development within the community [Data: Entities (1557); Relationships (1896)].",
#    'rank': 8.5,
#    'index_name': 'gragidx01',
#    'index_id': '131'},
#   {'id': '75',
#    'title': 'Tacoma Community Overview',
#    'occurrence weight': 0.1794871794871795,
#    'content': "# Tacoma Community Overview\n\nThe Tacoma community is a diverse and historically rich area in Washington state, known for its educational institutions, significant ethnic communities, and historical industrial activities. Key entities include the city of Tacoma, the Tacoma School of the Arts, the Science and Math Institute (SAMI), and notable ethnic communities such as the African American, Cambodian-American, and Samoan communities. These entities are interconnected through various relationships, contributing to the community's unique cultural and social fabric.\n\n## Tacoma's Historical and Cultural Significance\n\nTacoma is a major city in Washington state with a rich history and cultural significance. Historically, it had large smelters for treating gold, silver, copper, and lead ores, which played a crucial role in its economic development. The city is also notable for its concentrated African American population, particularly in Inner Tacoma. Additionally, Tacoma was a proposed name for the state of Washington during the statehood process in 1889, highlighting its historical importance [Data: Entities (2184); Relationships (1060, 2419)].\n\n## Educational Institutions in Tacoma\n\nTacoma is home to several prominent educational institutions, including the Tacoma School of the Arts and the Science and Math Institute (SAMI). The Tacoma School of the Arts is a public arts-focused high school, while SAMI is a high school focused on science and math. These institutions contribute to the city's reputation as a hub for education and innovation, attracting students from diverse backgrounds [Data: Entities (2582, 2586); Relationships (1284, 1288, 2423, 2424)].\n\n## Significant Ethnic Communities in Tacoma\n\nTacoma is home to significant ethnic communities, including the African American, Cambodian-American, and Samoan communities. The African American population is particularly concentrated in Inner Tacoma, while the Cambodian-American community is one of the largest in the United States. The Samoan community in the Seattle-Tacoma area is also significant, with more than 15,000 people of Samoan ancestry. These communities contribute to the city's cultural diversity and social dynamics [Data: Entities (2400, 2385, 2393, 2386); Relationships (2401, 2391, 2420, 2421, 2422)].\n\n## Tacoma's Role in the Seattle-Tacoma Designated Market Area\n\nTacoma is part of the Seattle-Tacoma Designated Market Area (DMA) as defined by Nielsen Media Research. This designation underscores Tacoma's importance in the regional media landscape and its influence on the broader Seattle-Tacoma metropolitan area. Being part of the DMA means that Tacoma's media outlets, such as The News Tribune, play a significant role in shaping public opinion and disseminating information in the region [Data: Claims (984)].\n\n## Tacoma's Transportation and Infrastructure\n\nTacoma boasts extensive waterways and transportation infrastructure, making it a significant hub in the region. The city's strategic location and infrastructure support its economic activities and connectivity with other parts of Washington state and beyond. This infrastructure is crucial for the movement of goods and people, contributing to Tacoma's role as a regional economic center [Data: Entities (2184)].",
#    'rank': 7.5,
#    'index_name': 'gragidx01',
#    'index_id': '75'},
#   {'id': '164',
#    'title': 'Ellis Island and Lyndon B. Johnson',
#    'occurrence weight': 0.10256410256410256,
#    'content': "# Ellis Island and Lyndon B. Johnson\n\nThe community revolves around Ellis Island, a historical site that served as a central immigration center in New York from 1892 to 1954. Key entities include Lyndon B. Johnson, who added Ellis Island to the National Park Service in May 1964, and various other entities connected to Ellis Island's history and significance. The relationships among these entities highlight the island's role in American immigration history and its preservation as a national monument.\n\n## Ellis Island's historical significance\n\nEllis Island is a historical site located in New Jersey and is part of the Statue of Liberty National Monument. It served as the central immigration center in New York from 1892 to 1954, acting as the gateway for millions of immigrants to the United States. This historical significance is preserved through its management by the National Park Service and its status as a museum of immigration since 1990 [Data: Entities (1751, 1779); Relationships (1672, 1752, 2242, 2248)].\n\n## Lyndon B. Johnson's contribution\n\nLyndon B. Johnson, the 36th President of the United States, played a crucial role in the preservation of Ellis Island by adding it to the National Park Service in May 1964. This action ensured the recognition and maintenance of Ellis Island as a historic site, highlighting Johnson's impact on American heritage preservation [Data: Entities (752); Relationships (1006, 2247)].\n\n## Ellis Island's connection to Jersey City\n\nEllis Island is connected to Jersey City by a short ferry ride, emphasizing its geographical and historical ties to New Jersey. This connection is significant as it highlights the island's accessibility and its role in the broader regional history [Data: Entities (1757); Relationships (2243)].\n\n## Impact of the National Origins Act\n\nThe National Origins Act, passed in 1924, significantly reduced immigration through Ellis Island. This legislation marked a pivotal change in the island's role as an immigration center, reflecting broader shifts in U.S. immigration policy during the early 20th century [Data: Entities (1760); Relationships (2245)].\n\n## Arne Peterssen's historical relevance\n\nArne Peterssen, a Norwegian seaman, was the last person detained on Ellis Island. His detention marks the end of an era for the island as an active immigration station, symbolizing the closure of a significant chapter in American immigration history [Data: Entities (1764); Relationships (2246)].\n\n## Ellis Island's jurisdictional dispute\n\nEllis Island was the subject of a jurisdictional dispute between New York and New Jersey, with part of the island located in New Jersey. This dispute underscores the complex legal and administrative history of the island, reflecting its importance to both states [Data: Relationships (2244)].\n\n## Ellis Island as part of the Statue of Liberty National Monument\n\nEllis Island is managed by the National Park Service as part of the Statue of Liberty National Monument. This management ensures the preservation of the island's historical and cultural significance, linking it to one of the most iconic symbols of American freedom and immigration [Data: Relationships (1752, 2242)].\n\n## Ellis Island's role as a museum of immigration\n\nIn 1990, Ellis Island was opened to the public as a museum of immigration. This transformation into a museum allows for the preservation and education of its rich history, providing a space for visitors to learn about the experiences of millions of immigrants who passed through its doors [Data: Entities (1779); Relationships (2248)].",
#    'rank': 8.5,
#    'index_name': 'gragidx01',
#    'index_id': '164'},
#   {'id': '196',
#    'title': 'TechGlobal and Vision Holdings in Manhattan',
#    'occurrence weight': 0.10256410256410256,
#    'content': "# TechGlobal and Vision Holdings in Manhattan\n\nThe community is centered around TechGlobal, a major technology company headquartered in Manhattan, New York City. TechGlobal is listed on the Global Exchange and was previously owned by Vision Holdings, a private equity firm also based in Manhattan. The relationships between these entities highlight significant financial and technological interactions within the community.\n\n## TechGlobal's prominence in the technology sector\n\nTechGlobal is a key player in the technology industry, powering 85% of premium smartphones. This highlights the company's substantial influence and market share in the tech sector. The company's headquarters in Manhattan further emphasizes its strategic importance in a major financial hub. [Data: Entities (1314); Relationships (1825)]\n\n## Vision Holdings' historical ownership of TechGlobal\n\nVision Holdings, a private equity firm based in Manhattan, previously owned TechGlobal. This historical relationship indicates that Vision Holdings had significant control and influence over TechGlobal's operations and strategic decisions until recently. The transition of ownership could have implications for both entities' future strategies and market positions. [Data: Entities (1313); Relationships (1822, 1823)]\n\n## TechGlobal's listing on the Global Exchange\n\nTechGlobal is listed on the Global Exchange, a financial institution also headquartered in Manhattan. This listing provides TechGlobal with access to capital markets and enhances its financial stability and growth potential. The relationship between TechGlobal and the Global Exchange underscores the interconnectedness of technology and finance within this community. [Data: Entities (1314, 1315); Relationships (1824)]\n\n## Financial implications of TechGlobal's market activities\n\nTechGlobal's activities on the Global Exchange have significant financial implications, not only for the company itself but also for investors and stakeholders. The company's performance on the exchange can influence market trends and investor confidence, making it a critical entity within the financial ecosystem of Manhattan. [Data: Entities (1314, 1315); Relationships (1824)]\n\n## Strategic location in Manhattan\n\nThe headquarters of TechGlobal, Vision Holdings, and the Global Exchange in Manhattan highlight the strategic importance of this location. Manhattan serves as a central hub for both technological innovation and financial activities, facilitating interactions and collaborations among these key entities. [Data: Entities (1314, 1313, 1315); Relationships (1823, 1824, 1825)]",
#    'rank': 8.5,
#    'index_name': 'gragidx01',
#    'index_id': '196'},
#   {'id': '69',
#    'title': 'U.S. Department of Defense and Los Angeles County',
#    'occurrence weight': 0.10256410256410256,
#    'content': "# U.S. Department of Defense and Los Angeles County\n\nThe community revolves around the U.S. Department of Defense (DoD) and Los Angeles County. The DoD oversees military personnel and installations in Washington state and has a significant presence in California. Los Angeles County is notable for being the largest origin of military recruits in the United States by county, with a significant population of illegal immigrants.\n\n## U.S. Department of Defense's oversight in Washington\n\nThe U.S. Department of Defense (DoD) is responsible for overseeing military personnel and installations in Washington state. This oversight includes managing military bases, personnel, and operations, which are critical for national security. The presence of the DoD in Washington highlights the strategic importance of the state in the broader defense infrastructure of the United States. [Data: Relationships (786)]\n\n## Significant military recruitment from Los Angeles County\n\nLos Angeles County is the largest origin of military recruits in the United States by county, with 1,437 individuals enlisting in the military in 2010. This high level of recruitment underscores the county's importance in supplying personnel to the U.S. military. The relationship between Los Angeles County and the DoD is crucial, as it reflects the county's contribution to national defense. [Data: Relationships (727)]\n\n## Los Angeles County's demographic and social challenges\n\nLos Angeles County is notable for having a significant population of illegal immigrants. This demographic characteristic presents various social, economic, and legal challenges for the county. The presence of a large immigrant population can impact local resources, law enforcement, and community relations. Understanding these dynamics is essential for addressing the needs and challenges of the county's residents. [Data: Entities (327)]\n\n## Strategic importance of California for the DoD\n\nThe U.S. Department of Defense maintains a significant presence in California, which is a strategic state for military operations and personnel management. California's large population and economic strength make it a vital region for defense-related activities. The state's infrastructure and resources support various military installations and operations, contributing to the overall defense capabilities of the United States. [Data: Entities (595)]",
#    'rank': 8.5,
#    'index_name': 'gragidx01',
#    'index_id': '69'},
#   {'id': '121',
#    'title': 'Tidal Basin and Surrounding Memorials',
#    'occurrence weight': 0.10256410256410256,
#    'content': "# Tidal Basin and Surrounding Memorials\n\nThe community centers around the Tidal Basin, a human-made reservoir in Washington, D.C., surrounded by several significant memorials including the Jefferson Memorial, Franklin Delano Roosevelt Memorial, George Mason Memorial, Martin Luther King Jr. Memorial, and the District of Columbia War Memorial. The Tidal Basin is also known for its picturesque environment, enhanced by the Japanese cherry trees that bloom every spring.\n\n## Tidal Basin as the central entity\n\nThe Tidal Basin is the central entity in this community, serving as the location around which several significant memorials are situated. This human-made reservoir is a key landmark in Washington, D.C., known for its scenic beauty and the annual cherry blossom bloom. The Tidal Basin's centrality enhances the historical and cultural value of the surrounding memorials, making it a focal point for both tourists and locals [Data: Entities (1274), Relationships (1657, 1812, 1809, 1810, 1813, 1811)].\n\n## Jefferson Memorial's significance\n\nThe Jefferson Memorial is a prominent national monument dedicated to Thomas Jefferson, located at the Tidal Basin. This neoclassical structure is not only an architectural marvel but also a symbol of American history and values. Its location at the Tidal Basin adds to its picturesque setting, attracting numerous visitors annually. The memorial's significance is further highlighted by its inclusion in various historical and cultural narratives [Data: Entities (1087), Claims (554), Relationships (1462, 1657)].\n\n## Franklin Delano Roosevelt Memorial's historical importance\n\nThe Franklin Delano Roosevelt Memorial, located around the Tidal Basin, commemorates the 32nd President of the United States. This memorial is unique in its design, featuring a series of outdoor rooms depicting different periods of Roosevelt's presidency. Its location around the Tidal Basin enhances its accessibility and visibility, making it a significant historical site. The memorial's design and location contribute to its role in educating the public about Roosevelt's legacy [Data: Entities (1379), Claims (552), Relationships (1809)].\n\n## George Mason Memorial's role in the community\n\nThe George Mason Memorial, situated around the Tidal Basin, honors George Mason, one of the Founding Fathers of the United States. This memorial is relatively less known compared to others but holds significant historical value. Its location around the Tidal Basin ensures that it is part of the broader narrative of American history represented by the memorials in this area. The memorial's presence contributes to the educational and cultural richness of the Tidal Basin community [Data: Entities (1380), Claims (553), Relationships (1810)].\n\n## Martin Luther King Jr. Memorial's cultural impact\n\nThe Martin Luther King Jr. Memorial, located around the Tidal Basin, is dedicated to the civil rights leader Martin Luther King Jr. This memorial is a powerful symbol of the struggle for equality and justice in the United States. Its location around the Tidal Basin places it within a context of other significant historical memorials, enhancing its cultural impact. The memorial attracts numerous visitors, serving as a place of reflection and inspiration [Data: Entities (1381), Claims (555), Relationships (1811)].\n\n## District of Columbia War Memorial's historical relevance\n\nThe District of Columbia War Memorial, located around the Tidal Basin, commemorates the residents of Washington, D.C., who served in World War I. This memorial is an important historical site, representing the contributions and sacrifices of local residents. Its location around the Tidal Basin ensures that it is part of the broader historical narrative of the area, contributing to the educational value of the community [Data: Entities (1382), Claims (556), Relationships (1812)].\n\n## Japanese cherry trees' contribution to the Tidal Basin's appeal\n\nTh ...
#    'rank': 8.5,
#    'index_name': 'gragidx01',
#    'index_id': '121'},
#   {'id': '130',
#    'title': 'General Grant National Memorial and Key Historical Figures',
#    'occurrence weight': 0.10256410256410256,
#    'content': "# General Grant National Memorial and Key Historical Figures\n\nThe community centers around the General Grant National Memorial, which is the final resting place of President Ulysses S. Grant. Key entities include Ulysses S. Grant, Alexander Robey Shepherd, and President Grant. The relationships among these entities highlight significant historical events and decisions, such as the modernization of the District of Columbia and the creation of the General Grant National Memorial.\n\n## General Grant National Memorial as a central historical site\n\nThe General Grant National Memorial is a significant historical site as it is the final resting place of President Ulysses S. Grant and the largest mausoleum in North America. This site not only commemorates President Grant but also serves as a symbol of his legacy. The memorial's location in New York further emphasizes its importance as a national landmark [Data: Entities (1874), Claims (663); Relationships (2027, 1730)].\n\n## Ulysses S. Grant's refusal to move the capital\n\nPresident Ulysses S. Grant played a crucial role in maintaining the capital's location in Washington, D.C. He refused to consider proposals to move the capital farther west and supported the Organic Act of 1871, which created a new territorial government for the District of Columbia. This decision had a lasting impact on the development and governance of the capital [Data: Entities (1131), Claims (418)].\n\n## Alexander Robey Shepherd's modernization projects\n\nAlexander Robey Shepherd, appointed by President Grant as Governor of the District of Columbia, authorized large projects that modernized the city. These projects significantly improved the infrastructure and urban landscape of Washington, D.C., although they also led to the bankruptcy of the city's government. Shepherd's actions had a profound impact on the city's development and financial stability [Data: Entities (1132), Claims (419, 421); Relationships (800, 1729, 1731)].\n\n## President Grant's appointment of Alexander Robey Shepherd\n\nPresident Grant's decision to appoint Alexander Robey Shepherd as Governor of the District of Columbia was a pivotal moment in the city's history. Shepherd's tenure was marked by ambitious modernization projects that transformed the city, although they also resulted in financial difficulties. This appointment highlights the close relationship between Grant and Shepherd and their shared vision for the capital's development [Data: Entities (1155), Relationships (1729, 1731)].\n\n## Historical significance of the General Grant National Memorial\n\nThe General Grant National Memorial holds immense historical significance as it honors President Ulysses S. Grant, a key figure in American history. The memorial not only serves as his final resting place but also as a testament to his contributions to the nation. Its status as the largest mausoleum in North America underscores its importance as a national monument [Data: Entities (1874), Claims (663); Relationships (1730)].",
#    'rank': 7.5,
#    'index_name': 'gragidx01',
#    'index_id': '130'},
#   {'id': '141',
#    'title': 'American Civil War and Key Legislative Actions',
#    'occurrence weight': 0.07692307692307693,
#    'content': "# American Civil War and Key Legislative Actions\n\nThe community revolves around the American Civil War, which saw significant contributions from California and New York City to support the Union. Key legislative actions during this period include the signing of the Compensated Emancipation Act by President Abraham Lincoln, which ended slavery in the District of Columbia. The relationships between these entities highlight the interconnectedness of states, legislative actions, and key figures during the war.\n\n## California's contribution to the Union\n\nDuring the American Civil War, California played a crucial role by sending gold shipments to support the Union. This financial support was vital in sustaining the Union's war efforts and highlights California's strategic importance during the conflict. The state's contribution underscores the broader national effort to preserve the Union and end slavery [Data: Relationships (33)].\n\n## New York City's support for the Union\n\nNew York City provided significant support to the Union during the American Civil War. This support included financial, logistical, and manpower contributions, which were essential in bolstering the Union's capabilities. New York City's involvement exemplifies the critical role that major urban centers played in the war effort, contributing to the Union's eventual victory [Data: Relationships (651)].\n\n## The Compensated Emancipation Act\n\nThe Compensated Emancipation Act, signed by President Abraham Lincoln, ended slavery in the District of Columbia, freeing about 3,100 slaves. This legislative action was a significant step towards the abolition of slavery in the United States and demonstrated the federal government's commitment to ending the institution of slavery. The act also set a precedent for future emancipation efforts [Data: Entities (1130); Claims (417); Relationships (650, 1728)].\n\n## Abraham Lincoln's legislative actions\n\nAbraham Lincoln, the 16th President of the United States, played a pivotal role during the American Civil War. One of his notable legislative actions was signing the Compensated Emancipation Act, which ended slavery in the District of Columbia. Lincoln's leadership and legislative efforts were instrumental in shaping the course of the war and the future of the nation [Data: Entities (1129); Claims (417); Relationships (1728)].\n\n## Impact of the American Civil War on federal government and population growth\n\nThe American Civil War led to the expansion of the federal government and notable growth in the population of various cities. The war necessitated increased federal oversight and intervention, which resulted in a more centralized and powerful federal government. Additionally, the conflict spurred population growth in cities as people moved to urban centers for economic opportunities and to support the war effort [Data: Entities (101)].",
#    'rank': 8.5,
#    'index_name': 'gragidx01',
#    'index_id': '141'},
#   {'id': '25',
#    'title': 'Explorers of the Strait of Juan de Fuca',
#    'occurrence weight': 0.07692307692307693,
#    'content': "# Explorers of the Strait of Juan de Fuca\n\nThe community revolves around the Strait of Juan de Fuca, a significant body of water discovered by Charles William Barkley. The strait is further explored by notable figures such as Francisco de Eliza, George Vancouver, and Manuel Quimper. The relationships among these explorers and the strait highlight its historical and geographical importance.\n\n## Strait of Juan de Fuca as a central entity\n\nThe Strait of Juan de Fuca is the central entity in this community, serving as a significant geographical landmark. It forms part of the northern border of Washington, along with the Strait of Georgia and Haro Strait. This strait's discovery and subsequent explorations have made it a crucial point of interest in the region's history and geography. [Data: Entities (2182); Relationships (1053, 2412, 2416, 2417, 2415)]\n\n## Charles William Barkley's discovery\n\nCharles William Barkley, the captain of the Imperial Eagle, discovered the Strait of Juan de Fuca in 1787. This discovery is a pivotal moment in the history of the region, marking the beginning of European exploration in the area. Barkley's role is well-documented and recognized, making him a key figure in this community. [Data: Entities (2174); Claims (824); Relationships (1057, 2412)]\n\n## Francisco de Eliza's exploration\n\nSpanish explorer Francisco de Eliza further explored the Strait of Juan de Fuca in 1791. His exploration contributed to the detailed mapping and understanding of the strait, highlighting the ongoing interest and significance of this body of water among European explorers. [Data: Entities (2196); Relationships (2416)]\n\n## George Vancouver's exploration\n\nBritish explorer George Vancouver further explored the Strait of Juan de Fuca in 1792. Vancouver's exploration efforts were part of a larger mission to chart the Pacific Northwest, and his work in the strait added valuable information to the region's nautical charts. [Data: Entities (2197); Relationships (2417)]\n\n## Manuel Quimper's exploration\n\nSpanish explorer Manuel Quimper further explored the Strait of Juan de Fuca in 1790. Quimper's exploration was part of Spain's efforts to assert its presence in the Pacific Northwest, and his work in the strait provided important insights into the region's geography. [Data: Entities (2195); Relationships (2415)]",
#    'rank': 7.5,
#    'index_name': 'gragidx01',
#    'index_id': '25'},
#   {'id': '183',
#    'title': 'William H. Seward and the Alaska Purchase',
#    'occurrence weight': 0.05128205128205128,
#    'content': "# William H. Seward and the Alaska Purchase\n\nThe community revolves around William H. Seward, who played a pivotal role in American history by negotiating the Alaska Purchase. This community includes significant entities such as the Alaska Purchase, Alaska Day, Fort Sitka, Andrew Johnson, and Tsar Alexander II. The relationships among these entities highlight the historical significance of the Alaska Purchase and its impact on the United States.\n\n## William H. Seward's central role\n\nWilliam H. Seward is the central figure in this community, having negotiated the Alaska Purchase with Russia for $7.2 million on March 30, 1867. His role as the United States Secretary of State under President Abraham Lincoln and his survival of an assassination attempt on the evening of Lincoln's assassination further underscore his importance. [Data: Entities (728); Claims (260, 571); Relationships (965, 966)]\n\n## Significance of the Alaska Purchase\n\nThe Alaska Purchase was a monumental event in American history, marking the acquisition of Alaska from Russia in 1867. This purchase expanded the territory of the United States and had long-term geopolitical implications. The formal transfer of Alaska took place at Fort Sitka, and this event is commemorated annually on Alaska Day. [Data: Entities (731, 732, 733); Relationships (969, 970)]\n\n## Role of Andrew Johnson\n\nAndrew Johnson, the President of the United States during the Alaska Purchase, played a significant role in the acquisition process. His presidency and support for the purchase were crucial in facilitating the transaction between the United States and Russia. [Data: Entities (729); Relationships (967)]\n\n## Tsar Alexander II's involvement\n\nTsar Alexander II, the Emperor of the Russian Empire, planned the sale of Alaska to the United States. His decision to sell Alaska was influenced by various geopolitical and economic factors, making him a key figure in this historical event. [Data: Entities (730); Relationships (968)]\n\n## Commemoration of Alaska Day\n\nAlaska Day is a legal holiday celebrated on October 18, commemorating the formal transfer of Alaska from Russia to the United States. This day serves as a reminder of the historical significance of the Alaska Purchase and its impact on American history. [Data: Entities (733); Relationships (970)]",
#    'rank': 8.5,
#    'index_name': 'gragidx01',
#    'index_id': '183'},
#   {'id': '9',
#    'title': 'Alaska Statehood Movement',
#    'occurrence weight': 0.05128205128205128,
#    'content': "# Alaska Statehood Movement\n\nThe community revolves around the Alaska Statehood Movement, which includes key entities such as Alaska's Constitutional Convention, the Alaska Statehood Committee, and James Wickersham. These entities played significant roles in the process leading to Alaska's statehood, with interconnected relationships that highlight their collective efforts.\n\n## Alaska's Constitutional Convention as a pivotal event\n\nAlaska's Constitutional Convention was a significant event that followed the momentum gained by the statehood movement after the 1946 territorial referendum. This convention was an integral part of the process leading to Alaska's statehood, marking a crucial step in the state's journey towards achieving full statehood status. The convention's outcomes laid the foundational legal and political framework for the new state. [Data: Entities (744); Relationships (488, 988)]\n\n## Role of the Alaska Statehood Committee\n\nThe Alaska Statehood Committee was deeply involved in the movement for Alaska's statehood. This committee's efforts were pivotal in organizing Alaska's Constitutional Convention, which played a crucial role in the journey towards achieving statehood for Alaska. The committee's advocacy and organizational skills were instrumental in mobilizing support and resources necessary for the statehood movement. [Data: Entities (743); Relationships (988)]\n\n## James Wickersham's advocacy for statehood\n\nJames Wickersham was a congressional delegate who strongly advocated for Alaska statehood. His involvement in the Alaska Statehood Committee underscores his commitment to the cause. Wickersham's efforts were significant in garnering political support and raising awareness about the importance of statehood for Alaska. His legacy is closely tied to the success of the statehood movement. [Data: Entities (742); Relationships (987)]\n\n## Interconnected relationships among key entities\n\nThe relationships among Alaska's Constitutional Convention, the Alaska Statehood Committee, and James Wickersham highlight the interconnected nature of the statehood movement. These entities worked collaboratively, with each playing a distinct yet complementary role in the process. The synergy among these entities was crucial in overcoming the challenges and opposition faced during the statehood campaign. [Data: Relationships (488, 987, 988)]\n\n## Historical significance of the 1946 territorial referendum\n\nThe 1946 territorial referendum was a turning point that provided the momentum needed for the statehood movement. The positive outcome of this referendum demonstrated the strong desire among Alaskans for statehood and set the stage for subsequent efforts, including the Constitutional Convention and the activities of the Statehood Committee. This referendum is a key historical milestone in Alaska's path to statehood. [Data: Entities (744, 743)]",
#    'rank': 8.5,
#    'index_name': 'gragidx01',
#    'index_id': '9'},
#   {'id': '78',
#    'title': 'Wenatchee River PCB Contamination',
#    'occurrence weight': 0.05128205128205128,
#    'content': "# Wenatchee River PCB Contamination\n\nThe community revolves around the Wenatchee River, which has been identified as having unhealthy levels of PCBs, particularly in mountain whitefish. The Washington State Department of Health has issued advisories against consuming these fish, based on studies conducted by the Department of Ecology. The relationships between these entities highlight the public health concerns and regulatory actions taken to address the contamination.\n\n## Wenatchee River's PCB Contamination\n\nThe Wenatchee River has been identified as having unhealthy levels of PCBs, particularly in mountain whitefish found in its waters. This contamination poses significant health risks to the public, especially those who consume fish from the river. The presence of PCBs in the river highlights the need for ongoing monitoring and remediation efforts to protect public health and the environment. [Data: Entities (2511); Relationships (1233, 2513)]\n\n## Public Health Advisory by Washington State Department of Health\n\nThe Washington State Department of Health has issued a public health advisory warning the public not to eat mountain whitefish from the Wenatchee River from Leavenworth downstream to where the river joins the Columbia. This advisory is based on the unhealthy levels of PCBs found in the fish, which can pose serious health risks to consumers. The advisory underscores the importance of public awareness and adherence to health guidelines to prevent exposure to harmful contaminants. [Data: Entities (2525); Claims (925); Relationships (2513)]\n\n## Role of the Department of Ecology\n\nThe Department of Ecology has conducted studies that led to the advisories issued by the Washington State Department of Health. These studies are crucial in identifying the sources and levels of PCB contamination in the Wenatchee River, thereby informing regulatory actions and public health advisories. The Department of Ecology's role highlights the importance of scientific research and environmental monitoring in addressing contamination issues. [Data: Entities (2566); Relationships (2514)]\n\n## Interconnectedness of Entities\n\nThe relationships between the Wenatchee River, the Washington State Department of Health, and the Department of Ecology illustrate a network of interconnected entities working together to address the PCB contamination issue. The Department of Ecology's studies inform the health advisories issued by the Washington State Department of Health, which in turn guide public behavior to mitigate health risks. This interconnectedness is essential for effective environmental and public health management. [Data: Relationships (1233, 2513, 2514)]\n\n## Health Risks of PCB Exposure\n\nPCBs are known to cause a range of adverse health effects, including cancer, immune system suppression, and neurological damage. The presence of PCBs in the Wenatchee River's mountain whitefish poses a significant health risk to individuals who consume these fish. The public health advisory issued by the Washington State Department of Health aims to prevent these health risks by discouraging the consumption of contaminated fish. [Data: Claims (925); Entities (2525)]",
#    'rank': 7.5,
#    'index_name': 'gragidx01',
#    'index_id': '78'},
#   {'id': '82',
#    'title': 'United States Supreme Court and Old Senate Chamber',
#    'occurrence weight': 0.02564102564102564,
# ...
#    'rank': 7.5,
#    'index_name': 'gragidx01',
#    'index_id': '118'},
#   {'id': '103',
#    'title': 'University of Alaska and Alaska Scholars Program',
#    'occurrence weight': 0.07692307692307693,
#    'content': "# University of Alaska and Alaska Scholars Program\n\nThe community centers around the University of Alaska, a land grant university that owns substantial acreage in Alaska and offers partial four-year scholarships to the top 10% of Alaska high school graduates through the Alaska Scholars Program. The program aims to retain top academic talent within the state by encouraging them to pursue higher education at the University of Alaska.\n\n## University of Alaska's substantial land ownership\n\nThe University of Alaska, as a land grant university, owns substantial acreage in the state of Alaska. This land ownership allows the university to manage and utilize these lands independently, which can have significant economic and environmental impacts on the state. The university's land management practices and policies are crucial in understanding its influence within the community. [Data: Claims (280); Relationships (506)]\n\n## Educational incentives through the Alaska Scholars Program\n\nThe University of Alaska has implemented the Alaska Scholars Program to combat the outflow of high academic achievers from the state. This program offers partial four-year scholarships to the top 10% of Alaska high school graduates, encouraging them to pursue higher education at the University of Alaska. This initiative is a strategic effort to retain talent within the state and enhance the university's academic community. [Data: Entities (1002); Claims (349); Relationships (1376)]\n\n## University of Alaska's role in the state's education system\n\nThe University of Alaska plays a pivotal role in the state's education system, not only by providing higher education opportunities but also by offering incentives to retain top students within the state. The university's efforts to attract and retain high-achieving students through the Alaska Scholars Program highlight its commitment to fostering academic excellence and supporting the state's educational goals. [Data: Entities (812, 1002); Claims (349)]\n\n## Impact of the Alaska Scholars Program on student retention\n\nThe Alaska Scholars Program has a significant impact on student retention within the state. By offering partial scholarships to the top 10% of high school graduates, the program aims to reduce the brain drain phenomenon, where top students leave the state for educational opportunities elsewhere. This initiative not only benefits the University of Alaska but also contributes to the overall development of the state's workforce and economy. [Data: Entities (1002); Claims (349)]\n\n## University of Alaska's independent land management\n\nAs a land grant university, the University of Alaska manages its substantial acreage independently. This autonomy in land management allows the university to make decisions that can have far-reaching implications for the state's environment and economy. Understanding the university's land management practices is essential for assessing its overall impact on the community. [Data: Claims (280); Relationships (506)]",
#    'rank': 7.5,
#    'index_name': 'gragidx01',
#    'index_id': '103'},
#   {'id': '39',
#    'title': 'Pacific Lutheran University and Pacific Lutheran Lutes',
#    'occurrence weight': 0.07692307692307693,
#    'content': "# Pacific Lutheran University and Pacific Lutheran Lutes\n\nThe community centers around Pacific Lutheran University, a private Lutheran university located in Tacoma, Washington. The university is closely associated with its sports team, the Pacific Lutheran Lutes, which competes in NCAA Division III. The relationships and claims highlight the university's significance in the region and its role in higher education and athletics.\n\n## Pacific Lutheran University as a major educational institution\n\nPacific Lutheran University is recognized as a significant educational institution in Washington. It is a private Lutheran university located in Tacoma, Washington, and is mentioned as one of the major research universities in the state. This highlights its importance in the academic and research community, contributing to its high impact rating. [Data: Entities (2596); Claims (959); Relationships (1299)]\n\n## Pacific Lutheran Lutes' role in NCAA Division III sports\n\nThe Pacific Lutheran Lutes are the sports team from Pacific Lutheran University, competing in NCAA Division III. This association with collegiate athletics enhances the university's visibility and influence, particularly in the realm of sports. The team's participation in NCAA competitions underscores the university's commitment to athletic excellence. [Data: Entities (2647); Claims (991); Relationships (2528)]\n\n## Geographical significance of Pacific Lutheran University\n\nPacific Lutheran University is located in Tacoma, Washington, which situates it within a significant urban area in the state. This geographical positioning enhances its accessibility and influence within the region, making it a pivotal institution for higher education in Washington. [Data: Entities (2596); Relationships (1299)]\n\n## Research contributions of Pacific Lutheran University\n\nThe university is mentioned as one of the major research universities in Washington, indicating its contributions to academic research and innovation. This status not only elevates the university's reputation but also attracts students, faculty, and funding, further solidifying its impact. [Data: Claims (959)]\n\n## Community engagement through sports\n\nThe Pacific Lutheran Lutes, as the university's sports team, play a significant role in community engagement. Their participation in NCAA Division III sports fosters a sense of community and school spirit, while also providing student-athletes with opportunities for personal and athletic development. [Data: Entities (2647); Relationships (2528)]",
#    'rank': 6.5,
#    'index_name': 'gragidx01',
#    'index_id': '39'},
#   {'id': '73',
#    'title': 'Alaska Airlines and Essential Air Service Program',
#    'occurrence weight': 0.05128205128205128,
#    'content': "# Alaska Airlines and Essential Air Service Program\n\nThe community centers around Alaska Airlines, a major airline based in Washington, and the Essential Air Service Program, a federal initiative that subsidizes air travel to remote and rural communities in the United States, including many in Alaska. The relationships between these entities highlight the importance of Alaska Airlines in providing essential air services to remote areas, supported by federal subsidies.\n\n## Alaska Airlines' pivotal role in the community\n\nAlaska Airlines is a major airline based in the United States, providing both domestic and international flights. It is the only major airline offering in-state travel in Alaska, making it a crucial entity for the state's connectivity and tourism industry. The airline's operations are significant for the local economy and the accessibility of remote areas. [Data: Entities (1028)]\n\n## Essential Air Service Program's support for remote communities\n\nThe Essential Air Service Program is a federal initiative that subsidizes air travel to remote and rural communities in the United States, including many in Alaska. This program ensures that these communities remain connected to the broader transportation network, which is vital for their economic and social well-being. The program's support for Alaska Airlines highlights the airline's importance in serving these remote areas. [Data: Entities (1027), Relationships (1419)]\n\n## Alaska Airlines' significant presence in Washington\n\nAlaska Airlines is a significant business entity in Washington, where it is based. The airline's operations in Washington contribute to the state's economy and its connectivity to other regions. This relationship underscores the airline's importance not only in Alaska but also in its home state of Washington. [Data: Relationships (1146)]\n\n## Economic impact of Alaska Airlines on remote communities\n\nAlaska Airlines' services, subsidized by the Essential Air Service Program, have a substantial economic impact on remote communities in Alaska. By providing reliable air travel, the airline supports local businesses, tourism, and access to essential services. This economic contribution is critical for the sustainability and development of these remote areas. [Data: Entities (1028), Relationships (1419)]\n\n## Federal subsidies' role in maintaining air connectivity\n\nThe federal subsidies provided by the Essential Air Service Program are crucial for maintaining air connectivity to remote and rural communities. These subsidies ensure that airlines like Alaska Airlines can continue to operate routes that might otherwise be economically unviable, thereby preserving essential transportation links for these communities. [Data: Entities (1027), Relationships (1419)]",
#    'rank': 7.5,
#    'index_name': 'gragidx01',
#    'index_id': '73'},
#   {'id': '93',
#    'title': 'Tsimshian Community on Annette Island',
#    'occurrence weight': 0.02564102564102564,
#    'content': "# Tsimshian Community on Annette Island\n\nThe Tsimshian community is centered around their settlement on Annette Island in Alaska, which was granted by U.S. President Grover Cleveland. The community includes the town of Metlakatla, founded by the Tsimshian people. The relationships between these entities highlight the historical and cultural significance of the Tsimshian settlement.\n\n## Tsimshian settlement on Annette Island\n\nThe Tsimshian people settled on Annette Island in Alaska in 1887. This settlement was a significant event in the history of the Tsimshian people, marking their establishment in a new region. The settlement on Annette Island is a key aspect of the Tsimshian community's identity and heritage. [Data: Entities (692); Relationships (467)]\n\n## Role of Grover Cleveland\n\nU.S. President Grover Cleveland played a crucial role in the Tsimshian settlement by granting them permission to settle on Annette Island. This decision by President Cleveland was instrumental in the establishment of the Tsimshian community in Alaska, providing them with a new homeland. [Data: Entities (693); Relationships (939)]\n\n## Founding of Metlakatla\n\nThe town of Metlakatla was founded by the Tsimshian people on Annette Island. Metlakatla serves as a central location for the Tsimshian community and is a testament to their resilience and ability to establish a thriving community in a new environment. [Data: Entities (694); Relationships (940)]\n\n## Cultural significance of the Tsimshian community\n\nThe Tsimshian community holds significant cultural importance due to their unique heritage and history. Their settlement on Annette Island and the founding of Metlakatla are key aspects of their cultural identity, reflecting their traditions and way of life. [Data: Entities (692, 694); Relationships (467, 940)]\n\n## Historical impact of the Tsimshian settlement\n\nThe historical impact of the Tsimshian settlement on Annette Island is profound, as it represents a pivotal moment in the history of the Tsimshian people. The settlement allowed the Tsimshian to preserve their culture and traditions while adapting to a new environment. [Data: Entities (692); Relationships (467, 939)]",
#    'rank': 7.5,
#    'index_name': 'gragidx01',
#    'index_id': '93'},
#   {'id': '57',
#    'title': 'Manila and Guerrero: Historical Connections',
#    'occurrence weight': 0.02564102564102564,
#    'content': "# Manila and Guerrero: Historical Connections\n\nThe community revolves around the historical connections between Manila, the capital of the Philippines, and Guerrero, a region in Mexico. These connections are primarily based on the descendants of the Muslim Caliph Hasan ibn Ali, who transited through California before playing a significant role in the wars of independence in Guerrero.\n\n## Manila as a key historical location\n\nManila, the capital of the Philippines, is a central entity in this community. It is historically significant as the place where descendants of the Muslim Caliph Hasan ibn Ali lived before their transit through California. This historical connection highlights Manila's role in the broader narrative of the Muslim Caliphate's influence and migration patterns. [Data: Entities (57)]\n\n## Guerrero's role in the wars of independence\n\nGuerrero, a region in Mexico, is another key entity in this community. The descendants of the Muslim Caliph Hasan ibn Ali played a significant role in the wars of independence in Guerrero. This highlights the region's importance in the historical context of independence movements and the diverse influences that shaped them. [Data: Entities (58), Relationships (449)]\n\n## Transit through California\n\nThe descendants of the Muslim Caliph Hasan ibn Ali transited through California on their way to Guerrero, Mexico. This transit route underscores the interconnectedness of different regions and the movement of influential groups across continents. It also highlights California's role as a transit point in this historical journey. [Data: Relationships (25)]\n\n## Historical influence of the Muslim Caliphate\n\nThe involvement of the descendants of the Muslim Caliph Hasan ibn Ali in both Manila and Guerrero underscores the historical influence of the Muslim Caliphate. Their migration and participation in significant historical events, such as the wars of independence in Guerrero, reflect the far-reaching impact of the Caliphate's legacy. [Data: Entities (57, 58), Relationships (25, 449)]",
#    'rank': 6.5,
#    'index_name': 'gragidx01',
#    'index_id': '57'}],
#  'entities': [],
#  'relationships': [],
#  'claims': [],
#  'sources': []}

# %% [markdown]
# ### Local Query
#
# Local search queries are best suited for narrow-focused questions that require an understanding of specific entities mentioned in the documents (e.g. What are the healing properties of chamomile?)

# %%
# %%time


def local_search(index_name: str | list[str], query: str, community_level: int) -> requests.Response:
    """Run a local query over the knowledge graph(s) associated with one or more indexes"""
    url = endpoint + "/query/local"
    # optional parameter: community level to query the graph at (default for local query = 2)
    request = {"index_name": index_name, "query": query, "community_level": community_level}
    return requests.post(url, json=request, headers=headers)


# perform a local query
local_response = local_search(
    index_name=index_name, query="Summarize the main topics found in this data", community_level=2
)
local_response_data = parse_query_response(local_response, return_context_data=True)
local_response_data
# Out:
# # Summary of Main Topics in the Data
#
# The data provided offers a comprehensive overview of California's historical, economic, cultural, and social landscape. Below is a summary of the main topics covered:
#
# ## Economic Dominance
# California boasts the largest economy of any U.S. state, with a gross state product of $4.0 trillion as of 2024. This economic strength is driven by diverse sectors such as technology, agriculture, and entertainment. The state's agricultural industry leads the nation in output, particularly in dairy, almonds, and grapes [Data: California and Its Key Relationships (222)]. Additionally, California plays a crucial role in the global supply chain, handling about 40% of goods imported to the U.S. through the Port of Los Angeles [Data: California and Its Key Relationships (222)].
#
# ## Historical and Cultural Significance
# California has a rich history, having been part of Mexico until it was ceded to the United States in 1848. The state was a focal point during the California Gold Rush, which led to significant social and demographic changes [Data: California and Its Key Relationships (222)]. Culturally, California is home to Hollywood, one of the largest film industries in the world, and Silicon Valley, a global technology hub [Data: California and Its Key Relationships (222)]. The state's diverse population includes significant communities of Mexican and Asian descent, contributing to its multicultural landscape [Data: California and Its Key Relationships (222)].
#
# ## Trade and Immigration Ties with Mexico
# Mexico is California's biggest trade partner, reflecting a deep economic interdependence. Historically, California was part of Mexico, and today, the Spanish language remains significant in the state [Data: California and Its Key Relationships (222)]. Additionally, Mexico is a major source of immigration to California, although net immigration has dropped to zero or less in recent years [Data: California and Its Key Relationships (222)].
#
# ## Political Influence and Trends
# California is a political trendsetter, often regarded as a bellwether for national policies. The state has a significant Democratic majority, with Democrats holding a substantial edge in congressional representation [Data: California and Its Key Relationships (222)]. California has also passed several progressive propositions, including those related to stem cell research and changes to the primary election process [Data: California and Its Key Relationships (222)].
#
# ## Environmental and Energy Challenges
# California faces numerous environmental challenges, including droughts, wildfires, and energy crises. The state experienced its worst drought from 2011 to 2017 and the deadliest wildfire season in 2018 [Data: California and Its Key Relationships (222)]. Additionally, California imports more electricity than any other state, primarily from hydroelectric power in the Pacific Northwest and coal- and natural gas-fired production from the desert Southwest [Data: California and Its Key Relationships (222)].
#
# ## Impact of Natural Disasters
# California is prone to various natural disasters, including earthquakes, tsunamis, and wildfires. The state is located in the Ring of Fire, making it susceptible to seismic activity. The 2018 wildfire season was particularly devastating, causing significant loss of life and property [Data: California and Its Key Relationships (222)].
#
# ## Educational and Technological Leadership
# California is a leader in education and technology, with the largest number of school students in the country and renowned institutions like Stanford and UC Berkeley. The state is also home to Silicon Valley, a global center for technology and innovation [Data: California and Its Key Relationships (222)]. This leadership in education and technology drives economic growth and positions California as a key player in the global knowledge economy.
#
# ## Social and Demographic Changes
# California has experienced significant social and demographic changes over the years. The state saw a net loss of population between 2020 and 2023, attributed to moves out of state, declining birth rates, and COVID-19 pandemic deaths [Data: California and Its Key Relationships (222)]. Additionally, the state's immigration patterns have shifted, with a decrease in immigration from Latin American countries and an increase from Asia [Data: California and Its Key Relationships (222)].
#
# ## Homelessness and Housing Issues
# California faces significant challenges related to homelessness and housing. The state has the highest number of homeless people in the country, with an estimated 171,521 homeless individuals as of 2022 [Data: California and Its Key Relationships (222)]. The housing bubble burst in 2007-2008 also had a lasting impact, leading to a significant decline in property values and an increase in foreclosures [Data: California and Its Key Relationships (222)].
#
# ## Cultural and Linguistic Diversity
# California is one of the most culturally and linguistically diverse areas in the world. The state has a high concentration of speakers of various languages, including Chinese, Vietnamese, and Punjabi [Data: California and Its Key Relationships (222)]. Additionally, California has historically been home to more than 70 indigenous languages [Data: California and Its Key Relationships (222)]. This diversity enriches the state's cultural fabric and contributes to its dynamic social landscape.
#
# These topics collectively paint a detailed picture of California's multifaceted identity, highlighting its economic power, cultural richness, and the various challenges it faces.
# CPU times: user 16.9 ms, sys: 2.16 ms, total: 19 ms
# Wall time: 16.9 s
# {'reports': [{'id': '222',
#    'title': 'California and Its Key Relationships',
#    'content': "# California and Its Key Relationships\n\nThe community revolves around California, a state with significant historical, economic, and cultural ties to various entities such as Mexico, New York, and Washington. California's relationships span across trade, immigration, and political influence, making it a pivotal player in both national and international contexts.\n\n## California's Economic Dominance\n\nCalifornia boasts the largest economy of any U.S. state, with a gross state product of $4.0 trillion as of 2024. This economic prowess is driven by diverse sectors including technology, agriculture, and entertainment. The state's agricultural industry leads the nation in output, particularly in dairy, almonds, and grapes [Data: Claims (7, 8, 145, 156, 160, +more)]. Additionally, California plays a crucial role in the global supply chain, handling about 40% of goods imported to the U.S. through the Port of Los Angeles [Data: Claims (9, 213)].\n\n## Historical and Cultural Significance\n\nCalifornia has a rich history, having been part of Mexico until it was ceded to the United States in 1848. The state was a focal point during the California Gold Rush, which led to significant social and demographic changes [Data: Claims (3, 4, 5, 7)]. Culturally, California is home to Hollywood, one of the largest film industries in the world, and Silicon Valley, a global technology hub [Data: Claims (10, 11, 222)]. The state's diverse population includes significant communities of Mexican and Asian descent, contributing to its multicultural landscape [Data: Entities (6, 376); Claims (88)].\n\n## Trade and Immigration Ties with Mexico\n\nMexico is California's biggest trade partner, reflecting a deep economic interdependence. Historically, California was part of Mexico, and today, the Spanish language remains significant in the state [Data: Entities (6); Claims (158)]. Additionally, Mexico is a major source of immigration to California, although net immigration has dropped to zero or less in recent years [Data: Entities (6); Claims (64)]. This relationship underscores the ongoing cultural and economic exchanges between the two regions.\n\n## Political Influence and Trends\n\nCalifornia is a political trendsetter, often regarded as a bellwether for national policies. The state has a significant Democratic majority, with Democrats holding a substantial edge in congressional representation [Data: Claims (207, 216, 218)]. California has also passed several progressive propositions, including those related to stem cell research and changes to the primary election process [Data: Claims (213)]. The state's political culture is idiosyncratic, reflecting its diverse and dynamic population.\n\n## Environmental and Energy Challenges\n\nCalifornia faces numerous environmental challenges, including droughts, wildfires, and energy crises. The state experienced its worst drought from 2011 to 2017 and the deadliest wildfire season in 2018 [Data: Claims (40, 41)]. Additionally, California imports more electricity than any other state, primarily from hydroelectric power in the Pacific Northwest and coal- and natural gas-fired production from the desert Southwest [Data: Claims (171, 172)]. These challenges highlight the need for sustainable environmental and energy policies.\n\n## Impact of Natural Disasters\n\nCalifornia is prone to various natural disasters, including earthquakes, tsunamis, and wildfires. The state is located in the Ring of Fire, making it susceptible to seismic activity. The 2018 wildfire season was particularly devastating, causing significant loss of life and property [Data: Claims (41, 47)]. These natural disasters have far-reaching impacts on the state's economy, infrastructure, and public safety.\n\n## Educational and Technological Leadership\n\nCalifornia is a leader in education and technology, with the largest number of school students in the country and renowned institutions like Stanford and UC Berkeley. The state is  ...
#    'index_name': 'gragidx01',
#    'index_id': '222'},
#   {'id': '222',
#    'title': 'California and Its Key Relationships',
#    'content': "# California and Its Key Relationships\n\nThe community revolves around California, a state with significant historical, economic, and cultural ties to various entities such as Mexico, New York, and Washington. California's relationships span across trade, immigration, and political influence, making it a pivotal player in both national and international contexts.\n\n## California's Economic Dominance\n\nCalifornia boasts the largest economy of any U.S. state, with a gross state product of $4.0 trillion as of 2024. This economic prowess is driven by diverse sectors including technology, agriculture, and entertainment. The state's agricultural industry leads the nation in output, particularly in dairy, almonds, and grapes [Data: Claims (7, 8, 145, 156, 160, +more)]. Additionally, California plays a crucial role in the global supply chain, handling about 40% of goods imported to the U.S. through the Port of Los Angeles [Data: Claims (9, 213)].\n\n## Historical and Cultural Significance\n\nCalifornia has a rich history, having been part of Mexico until it was ceded to the United States in 1848. The state was a focal point during the California Gold Rush, which led to significant social and demographic changes [Data: Claims (3, 4, 5, 7)]. Culturally, California is home to Hollywood, one of the largest film industries in the world, and Silicon Valley, a global technology hub [Data: Claims (10, 11, 222)]. The state's diverse population includes significant communities of Mexican and Asian descent, contributing to its multicultural landscape [Data: Entities (6, 376); Claims (88)].\n\n## Trade and Immigration Ties with Mexico\n\nMexico is California's biggest trade partner, reflecting a deep economic interdependence. Historically, California was part of Mexico, and today, the Spanish language remains significant in the state [Data: Entities (6); Claims (158)]. Additionally, Mexico is a major source of immigration to California, although net immigration has dropped to zero or less in recent years [Data: Entities (6); Claims (64)]. This relationship underscores the ongoing cultural and economic exchanges between the two regions.\n\n## Political Influence and Trends\n\nCalifornia is a political trendsetter, often regarded as a bellwether for national policies. The state has a significant Democratic majority, with Democrats holding a substantial edge in congressional representation [Data: Claims (207, 216, 218)]. California has also passed several progressive propositions, including those related to stem cell research and changes to the primary election process [Data: Claims (213)]. The state's political culture is idiosyncratic, reflecting its diverse and dynamic population.\n\n## Environmental and Energy Challenges\n\nCalifornia faces numerous environmental challenges, including droughts, wildfires, and energy crises. The state experienced its worst drought from 2011 to 2017 and the deadliest wildfire season in 2018 [Data: Claims (40, 41)]. Additionally, California imports more electricity than any other state, primarily from hydroelectric power in the Pacific Northwest and coal- and natural gas-fired production from the desert Southwest [Data: Claims (171, 172)]. These challenges highlight the need for sustainable environmental and energy policies.\n\n## Impact of Natural Disasters\n\nCalifornia is prone to various natural disasters, including earthquakes, tsunamis, and wildfires. The state is located in the Ring of Fire, making it susceptible to seismic activity. The 2018 wildfire season was particularly devastating, causing significant loss of life and property [Data: Claims (41, 47)]. These natural disasters have far-reaching impacts on the state's economy, infrastructure, and public safety.\n\n## Educational and Technological Leadership\n\nCalifornia is a leader in education and technology, with the largest number of school students in the country and renowned institutions like Stanford and UC Berkeley. The state is  ...
#    'index_name': 'gragidx01',
#    'index_id': '222'}],
#  'entities': [{'id': '334',
#    'entity': 'CENSUS',
#    'description': 'The process by which the population of California was reported',
#    'number of relationships': '0',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 334},
#   {'id': '501',
#    'entity': 'CONGRESSIONAL RESEARCH SERVICE',
#    'description': 'The Congressional Research Service reported on the economic conditions of the San Joaquin Valley in 2005',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 501},
#   {'id': '340',
#    'entity': 'MIGRATION',
#    'description': "The movement of people, which has affected California's population trends",
#    'number of relationships': '0',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 340},
#   {'id': '505',
#    'entity': 'UTILITIES',
#    'description': "Utilities are a major sector of California's economy, contributing to its overall economic output",
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 505},
#   {'id': '859',
#    'entity': '2015 AMERICAN COMMUNITY SURVEY',
#    'description': "The 2015 American Community Survey estimated the racial and ethnic composition of Alaska's population",
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 859},
#   {'id': '403',
#    'entity': 'SPANISH',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 403},
#   {'id': '322',
#    'entity': 'US CENSUS BUREAU',
#    'description': "The organization that reported California's population statistics",
#    'number of relationships': '0',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 322},
#   {'id': '2309',
#    'entity': 'WARM',
#    'description': 'The type of climate found in the western side of Washington',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 2309},
#   {'id': '506',
#    'entity': 'GOVERNMENT',
#    'description': "Government is a major sector of California's economy, contributing to its overall economic output",
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 506},
#   {'id': '504',
#    'entity': 'TRANSPORTATION',
#    'description': "Transportation is a major sector of California's economy, heavily influenced by its ports and infrastructure",
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 504},
#   {'id': '892',
#    'entity': 'ENERGY INFORMATION ADMINISTRATION',
#    'description': "The Energy Information Administration provides data on energy production, including Alaska's oil reserves",
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 892},
#   {'id': '508',
#    'entity': 'EDUCATION AND HEALTH SERVICES',
#    'description': "Education and health services are a major sector of California's economy, contributing to its overall economic output",
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 508},
#   {'id': '513',
#    'entity': 'FARMING',
#    'description': "Farming is a key component of California's agriculture sector, with significant sales and technological improvements",
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 513},
#   {'id': '509',
#    'entity': 'LEISURE AND HOSPITALITY',
#    'description': "Leisure and hospitality are a major sector of California's economy, contributing to its overall economic output",
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 509},
#   {'id': '345',
#    'entity': 'IMMIGRATION PATTERN',
#    'description': 'The shift in the origin of immigrants to California',
#    'number of relationships': '0',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 345},
#   {'id': '511',
#    'entity': 'MANUFACTURING',
#    'description': "Manufacturing is a significant sector of California's economic output",
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 511},
#   {'id': '671',
#    'entity': 'CALIFORNIA STATE AGENCIES',
#    'description': 'California state agencies provide open data through the data.ca.gov portal',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 671},
#   {'id': '2622',
#    'entity': 'INTERNATIONAL EXAMINER',
#    'description': 'A publication in Seattle for the Asian community',
#    'number of relationships': '0',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 2622},
#   {'id': '2659',
#    'entity': 'NIELSEN MEDIA RESEARCH',
#    'description': 'A company that divides Washington into four Designated Market Areas',
#    'number of relationships': '0',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 2659},
#   {'id': '1912',
#    'entity': 'IMMIGRATION STATISTICS',
#    'description': 'Immigration statistics show New York as a leading recipient of migrants from around the globe',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 1912}],
#  'relationships': [{'id': '182',
#    'source': 'CALIFORNIA',
#    'target': 'SPANISH',
#    'description': 'Spanish is the most commonly spoken language in California after English',
#    'weight': '9.0',
#    'rank': '360',
#    'links': '8',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 182},
#   {'id': '229',
#    'source': 'CALIFORNIA',
#    'target': 'TRANSPORTATION',
#    'description': "Transportation is a major sector of California's economy",
#    'weight': '9.0',
#    'rank': '360',
#    'links': '8',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 229},
#   {'id': '230',
#    'source': 'CALIFORNIA',
#    'target': 'UTILITIES',
#    'description': "Utilities are a major sector of California's economy",
#    'weight': '9.0',
#    'rank': '360',
#    'links': '8',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 230},
#   {'id': '231',
#    'source': 'CALIFORNIA',
#    'target': 'GOVERNMENT',
#    'description': "Government is a major sector of California's economy",
#    'weight': '9.0',
#    'rank': '360',
#    'links': '8',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 231},
#   {'id': '233',
#    'source': 'CALIFORNIA',
#    'target': 'EDUCATION AND HEALTH SERVICES',
#    'description': "Education and health services are a major sector of California's economy",
#    'weight': '9.0',
#    'rank': '360',
#    'links': '8',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 233},
#   {'id': '234',
#    'source': 'CALIFORNIA',
#    'target': 'LEISURE AND HOSPITALITY',
#    'description': "Leisure and hospitality are a major sector of California's economy",
#    'weight': '9.0',
#    'rank': '360',
#    'links': '8',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 234},
#   {'id': '236',
#    'source': 'CALIFORNIA',
#    'target': 'MANUFACTURING',
#    'description': "Manufacturing is a significant sector of California's economic output",
#    'weight': '9.0',
#    'rank': '360',
#    'links': '8',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 236},
#   {'id': '238',
#    'source': 'CALIFORNIA',
#    'target': 'FARMING',
#    'description': "Farming is a key component of California's agriculture sector",
#    'weight': '9.0',
#    'rank': '360',
#    'links': '8',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 238},
#   {'id': '528',
#    'source': 'ALASKA',
#    'target': '2015 AMERICAN COMMUNITY SURVEY',
#    'description': "The 2015 American Community Survey estimated the racial and ethnic composition of Alaska's population",
#    'weight': '2.0',
#    'rank': '182',
#    'links': '2',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 528},
#   {'id': '559',
#    'source': 'ALASKA',
#    'target': 'ENERGY INFORMATION ADMINISTRATION',
#    'description': "The Energy Information Administration provides data on Alaska's oil reserves",
#    'weight': '7.0',
#    'rank': '182',
#    'links': '2',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 559},
#   {'id': '2032',
#    'source': 'NEW YORK',
#    'target': 'IMMIGRATION STATISTICS',
#    'description': 'Immigration statistics show New York as a leading recipient of migrants from around the globe',
#    'weight': '8.0',
#    'rank': '192',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 2032},
#   {'id': '2447',
#    'source': 'WESTERN WASHINGTON',
#    'target': 'WARM',
#    'description': 'Western Washington has a warm-summer Mediterranean climate',
#    'weight': '8.0',
#    'rank': '7',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 2447},
#   {'id': '673',
#    'source': 'SAN JOAQUIN VALLEY',
#    'target': 'CONGRESSIONAL RESEARCH SERVICE',
#    'description': 'The Congressional Research Service reported on the economic conditions of the San Joaquin Valley in 2005',
#    'weight': '7.0',
#    'rank': '5',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 673},
#   {'id': '879',
#    'source': 'STATE OF CALIFORNIA',
#    'target': 'CALIFORNIA STATE AGENCIES',
#    'description': 'California state agencies provide open data related to the State of California',
#    'weight': '7.0',
#    'rank': '4',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'gragidx01',
#    'index_id': 879}],
#  'claims': [],
#  'sources': [{'id': '80',
#    'text': ' Tuolumne River.\nThe Klamath and Trinity Rivers drain a large area in far northwestern California. The Eel River and Salinas River each drain portions of the California coast, north and south of San Francisco Bay, respectively. The Mojave River is the primary watercourse in the Mojave Desert, and the Santa Ana River drains much of the Transverse Ranges as it bisects Southern California. The Colorado River forms the state\'s southeast border with Arizona.\nMost of California\'s major rivers are dammed as part of two massive water projects: the Central Valley Project, providing water for agriculture in the Central Valley, and the California State Water Project diverting water from Northern to Southern California. The state\'s coasts, rivers, and other bodies of water are regulated by the California Coastal Commission.\n\n\n=== Regions ===\n\nCalifornia is traditionally separated into Northern California and Southern California, divided by a straight border which runs across the state, separating the northern 48 counties from the southern 10 counties. Despite the persistence of the northern-southern divide, California is more precisely divided into many regions, multiple of which stretch across the northern-southern divide.\n\nMajor divisions\nNorthern California\nSouthern California\nRegions\n\n\n=== Cities and towns ===\n\nThe state has 483 incorporated cities and towns, of which 461 are cities and 22 are towns. Under California law, the terms "city" and "town" are explicitly interchangeable; the name of an incorporated municipality in the state can either be "City of (Name)" or "Town of (Name)".\nSacramento became California\'s first incorporated city on February 27, 1850. San Jose, San Diego, and Benicia tied for California\'s second incorporated city, each receiving incorporation on March 27, 1850. Mountain House became the state\'s most recent and 483rd incorporated municipality on July 1, 2024.\nThe majority of these cities and towns are within one of five metropolitan areas: the Los Angeles Metropolitan Area, the San Francisco Bay Area, the Riverside-San Bernardino Area, the San Diego metropolitan area, or the Sacramento metropolitan area.\n\n\n== Demographics ==\n\n\n=== Population ===\n\nPresently, close to one out of every nine United States residents lives in California. The United States Census Bureau reported that the population of California was 39.54 million on April 1, 2020, a 6.13% increase since the 2010 census. During that decade, the state\'s population grew more slowly than the rest of the nation, resulting in the loss of one seat on the US House of Representatives, the first loss in its entire history. The estimated state population in 2023 was 38.94 million. For well over a century (1900–2020), California experienced steady population growth. Even while the rate of growth began to slow by the 1990s, some growth continued into the first two decades of the 21st century; California added an average of around 400,000 people per year to its population during the period 1940–2020. Then in 2020, the state began to experience population declines continuing every year, attributable mostly to moves out of state but also due to declining birth rates, COVID-19 pandemic deaths, and less internal migration from other states to California. According to the U.S. Census Bureau, between 2021 and 2022, 818,000 California residents moved out of state with emigrants listing high cost of living, high taxes, and a difficult business environment as the motivation. The net loss of population in California between July 2020 and July 2023 was 433,000.\n\nThe Greater Los Angeles Area is the second-largest metropolitan area in the United States (U.S.), while Los Angeles is the second-largest city in the U.S. Conversely, San Francisco is the most densely-populated city in California and one of the most densely populated cities in the U.S.. Also, Los Angeles County has held the title of most populous U.S. county for decades ...
#   {'id': '10',
#    'text': " largest and second-largest U.S. ports respectively, the Port of Los Angeles and the Port of Long Beach in Southern California collectively play a pivotal role in the global supply chain, together hauling in about 40% of all imports to the United States by TEU volume. The Port of Oakland and Port of Hueneme are the 10th and 26th largest seaports in the U.S., respectively, by number of TEUs handled.\nThe five largest sectors of employment in California are trade, transportation, and utilities; government; professional and business services; education and health services; and leisure and hospitality. In output, the five largest sectors are financial services, followed by trade, transportation, and utilities; education and health services; government; and manufacturing. California has an unemployment rate of 3.9% as of September 2022.\nCalifornia's economy is dependent on trade and international related commerce accounts for about one-quarter of the state's economy, and representing 7% of their GDP; California's biggest trade partner is Mexico. In 2008, California exported $144 billion worth of goods, up from $134 billion in 2007 and $127 billion in 2006. Vehicles, computers and electronic products are California's top export, accounting for 42 percent of all the state's exports in 2008; over 50 car companies operate in California, such as Tesla and Mazda.\n\n\n=== Agriculture ===\n\nAgriculture is an important sector in California's economy. According to the USDA in 2011, the three largest California agricultural products by value were milk and cream, shelled almonds, and grapes. Farming-related sales more than quadrupled over the past three decades, from $7.3 billion in 1974 to nearly $31 billion in 2004. This increase has occurred despite a 15 percent decline in acreage devoted to farming during the period, and water supply suffering from chronic instability. Factors contributing to the growth in sales-per-acre include more intensive use of active farmlands and technological improvements in crop production. In 2008, California's 81,500 farms and ranches generated $36.2 billion products revenue. In 2011, that number grew to $43.5 billion products revenue. The agriculture sector accounts for two percent of the state's GDP and employs around three percent of its total workforce.\n\n\n=== Income ===\n\nPer capita GDP in 2021 was $85,546, ranking fourth in the nation. Per capita income varies widely by geographic region and profession. The Central Valley is the most impoverished, with migrant farm workers making less than minimum wage. According to a 2005 report by the Congressional Research Service, the San Joaquin Valley was characterized as one of the most economically depressed regions in the United States, on par with the region of Appalachia.\nUsing the supplemental poverty measure, California has a poverty rate of 23.5%, the highest of any state in the country. However, using the official measure the poverty rate was only 13.3% as of 2017. Many coastal cities include some of the wealthiest per-capita areas in the United States. The high-technology sectors in Northern California, specifically Silicon Valley, in Santa Clara and San Mateo counties, have emerged from the economic downturn caused by the dot-com bust.\nIn 2019, there were 1,042,027 millionaire households in the state, more than any other state in the nation. In 2010, California residents were ranked first among the states with the best average credit score of 754.\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\n\n\n=== State finances ===\n\nState spending increased from $56 billion in 1998 to $127 billion in 2011. California has the third highest per capita spending on welfare among the states, as well as the highest spending on welfare at $6.67 billion. In January 2011, California's total debt was at least $265 billion. On June 27, 2013, Governor Jerry Brown signed a balanced budget (no deficit) for the state, its first in decades; however, ...
#   {'id': '22',
#    'text': "ppen climate classification: Cfb), and a subarctic oceanic climate (Köppen Cfc) in the northern parts, with cool summers and relatively mild winters. On an annual basis, the southeast is both the wettest and warmest part of Alaska with milder temperatures in the winter and high precipitation throughout the year. Juneau averages over 50 in (130 cm) of precipitation a year, and Ketchikan averages over 150 in (380 cm). This is also the only region in Alaska in which the average daytime high temperature is above freezing during the winter months.The climate of Anchorage and south central Alaska is mild by Alaskan standards due to the region's proximity to the seacoast. While the area gets less rain than southeast Alaska, it gets more snow, and days tend to be clearer. On average, Anchorage receives 16 in (41 cm) of precipitation a year, with around 75 in (190 cm) of snow, although there are areas in the south central which receive far more snow. It is a subarctic climate (Köppen: Dfc) due to its brief, cool summers.\nThe climate of western Alaska is determined in large part by the Bering Sea and the Gulf of Alaska. It is a subarctic oceanic climate in the southwest and a continental subarctic climate farther north. The temperature is somewhat moderate considering how far north the area is. This region has a tremendous amount of variety in precipitation. An area stretching from the northern side of the Seward Peninsula to the Kobuk River valley (i.e., the region around Kotzebue Sound) is technically a desert, with portions receiving less than 10 in (25 cm) of precipitation annually. On the other extreme, some locations between Dillingham and Bethel average around 100 in (250 cm) of precipitation.\nThe climate of the interior of Alaska is subarctic and is a classic example of a continental subarctic climate, except in a few valleys where the climate approaches humid continental (Köppen: Dfb). Some of the highest and lowest temperatures in Alaska occur around the area near Fairbanks. Summers are warm (albeit generally short) and may have temperatures reaching into the 90s °F (the low-to-mid 30s °C), while in the long and very cold winters, the temperature can fall below −60 °F (−51 °C). Precipitation is sparse in the Interior, often less than 10 in (25 cm) a year, but what precipitation falls in the winter tends to stay the entire winter.\nThe highest and lowest recorded temperatures in Alaska are both in the Interior. The highest is 100 °F (38 °C) in Fort Yukon (which is just 8 mi or 13 km inside the arctic circle) on June 27, 1915, making Alaska tied with Hawaii as the state with the lowest high temperature in the United States. The lowest official Alaska temperature is −80 °F (−62 °C) in Prospect Creek on January 23, 1971, one degree above the lowest temperature recorded in continental North America (in Snag, Yukon, Canada).\nThe climate in the extreme north of Alaska, north of the Brooks Range, is Arctic (Köppen: ET) with long, very cold winters and short, cool summers. Even in July, the average low temperature in Utqiaġvik is 34 °F (1 °C). Precipitation is light in this part of Alaska, with many places averaging less than 10 in (25 cm) per year, mostly as snow which stays on the ground almost the entire year.\n\n\n=== Flora and fauna ===\n\n\n== Demographics ==\n\nThe United States Census Bureau found in the 2020 United States census that the population of Alaska was 733,391 on April 1, 2020, a 3.3% increase since the 2010 United States census. According to the 2010 United States Census, the U.S. state of Alaska had a population of 710,231, a 13.3% increase from 626,932 at the 2000 U.S. census.\nIn 2020, Alaska ranked as the 48th largest state by population, ahead of only Vermont and Wyoming. Alaska is the least densely populated state, and one of the most sparsely populated areas in the world, at 1.2 inhabitants per square mile (0.46/km2), with the next state, Wyoming, at 5.8 inhabitants per square mile (2.2/km2). A ...
#   {'id': '8',
#    'text': '\'s de jure and de facto official language. According to the 2021 American Community Survey conducted by the United States Census Bureau, 56.08% (20,763,638) of California residents age 5 and older spoke only English at home, while 43.92% spoke another language at home. 60.35% of people who speak a language other than English at home are able to speak English "well" or "very well", with this figure varying significantly across the different linguistic groups. Like most U.S. states (32 out of 50), California law enshrines English as its official language, and has done so since the passage of Proposition 63 by California voters in 1986. Various government agencies do, and are often required to, furnish documents in the various languages needed to reach their intended audiences.\n\nSpanish is the most commonly spoken language in California, behind English, spoken by 28.18% (10,434,308) of the population (in 2021). The Spanish language has been spoken in California since 1542 and is deeply intertwined with California\'s cultural landscape and history. Spanish was the official administrative language of California through the Spanish and Mexican eras, until 1848. Following the U.S. Conquest of California and the Treaty of Guadalupe-Hidalgo, the U.S. Government guaranteed the rights of Spanish-speaking Californians. The first Constitution of California was written in both languages at the Monterey Constitutional Convention of 1849 and protected the rights of Spanish speakers to use their language in government proceedings and mandating that all government documents be published in both English and Spanish.\nDespite the initial recognition of Spanish by early American governments in California, the revised 1879 constitution stripped the rights of Spanish speakers and the official status of Spanish. The growth of the English-only movement by the mid-20th century led to the passage of 1986 California Proposition 63, which enshrined English as the only official language in California and ended Spanish language instruction in schools. 2016 California Proposition 58 reversed the prohibition on bilingual education, though there are still many barriers to the proliferation of Spanish bilingual education, including a shortage of teachers and lack of funding. The government of California has since made efforts to promote Spanish language access and bilingual education, as have private educational institutions in California. Many businesses in California promote the usage of Spanish by their employees, to better serve both California\'s Hispanic population and the larger Spanish-speaking world.\nCalifornia has historically been one of the most linguistically diverse areas in the world, with more than 70 indigenous languages derived from 64 root languages in six language families. A survey conducted between 2007 and 2009 identified 23 different indigenous languages among California farmworkers. All of California\'s indigenous languages are endangered, although there are now efforts toward language revitalization. California has the highest concentration nationwide of Chinese, Vietnamese and Punjabi speakers.\nAs a result of the state\'s increasing diversity and migration from other areas across the country and around the globe, linguists began noticing a noteworthy set of emerging characteristics of spoken American English in California since the late 20th century. This variety, known as California English, has a vowel shift and several other phonological processes that are different from varieties of American English used in other regions of the United States.\n\n\n=== Religion ===\n\nThe largest religious denominations by number of adherents as a percentage of California\'s population in 2014 were the Catholic Church with 28 percent, Evangelical Protestants with 20 percent, and Mainline Protestants with 10 percent. Together, all kinds of Protestants accounted for 32 percent. Those unaffiliated with any religion represented 27 perc ...
